# %%
import re
import time
import random
import pandas as pd
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.proxy import Proxy, ProxyType
from selenium.webdriver.common.action_chains import ActionChains

# %%
def convert(seconds): 
    seconds = seconds % (24 * 3600) 
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60
    return "%dh %02dm %02ds" % (hour, minutes, seconds)
# Define the description/about me exclusion list
    # Actual contents hidden
exclusion_list = ['']
# Define Instagram exclusion list
insta_exclusion_list = ['Instagram', 'Insta', 'IG', 'The Gram', 'Gram', 'instagram', 'insta', 'ig', 'the gram', 'gram', '@']
insta_puncuation_list = [':', '-', ' -', ' :', '@']
# Define FaceBook email
emailFB = ''
# Define FaceBook password
pwFB = ''
# Get the date for today and convert it to a string
date = datetime.now().strftime("%Y-%m-%d")

# %%
# TINDER
service = 'Tinder'
# Read the swiping history XLSX into a DataFrame
history_tinder = pd.read_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, header = 0)
# Define a start time
startTime = time.time()
# Define URL
tinder = 'https://tinder.com/?lang=en'
# Instantiate an Options object
option = webdriver.ChromeOptions()
#Remove navigator.webdriver flag
option.add_argument('--disable-blink-features=AutomationControlled')
# Change the resolution of the browser
option.add_argument("window-size=1920,1080")
# Adjusting the user agent
option.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36")
#Open Browser
driver = webdriver.Chrome(executable_path='chromedriver.exe', options=option)
# Open the specfied URL
driver.get(tinder)
# Sleep to avoid errors
time.sleep(random.uniform(2.0, 3.0))
# Find the login button and click it
login_button_tinder = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div/div/header/div/div[2]/div[2]/button').click()
# Sleep to avoid errors
time.sleep(random.uniform(5.0, 6.0))
# Define the Tinder window
window_tinder = driver.window_handles[0]
# Find the LOG IN WITH FACEBOOK button and click it
login_with_facebok_button = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/div[1]/div/div[3]/span/div[2]/button').click()
# Sleep to avoid errors
time.sleep(random.uniform(2.0, 3.0))
# Define the Facebook window
window_facebook = driver.window_handles[1]
# Switch to the Facebook window
driver.switch_to_window(window_facebook)
# Find the Email or Phone input field and type email
email_field = driver.find_element_by_xpath('/html/body/div/div[2]/div[1]/form/div/div[1]/div/input').send_keys(emailFB)
# Find the password input field and type PW
PW_field = driver.find_element_by_xpath('/html/body/div/div[2]/div[1]/form/div/div[2]/div/input').send_keys(pwFB)
# Click the login button
login_button_facebook = driver.find_element_by_xpath('//*[@id="u_0_0"]').click()
# Sleep to avoid errors
time.sleep(random.uniform(5.0, 6.0))
# Switch to the Tinder window
driver.switch_to_window(window_tinder)
# Find the button to allow GPS tracking
gps_allow = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/div/div/div[3]/button[1]').click()
# Sleep to avoid errors
time.sleep(random.uniform(1.0, 2.0))
# Enable notifications
notifications_allow = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/div/div/div[3]/button[1]').click()
# Sleep to avoid errors
time.sleep(random.uniform(4.0, 8.0))
# Click accept to accept cookies
cookies_okay = driver.find_element_by_xpath('//*[@id="content"]/div/div[2]/div/div/div[1]/button').click()

# THIS IS WHERE THE WHILE LOOP WILL START
like_quantity_tinder = random.randrange(10, 20)
pass_quantity_tinder = 0
no_desc_tinder = 0
had_exclusion_tinder = 0
likesUsed_tinder = 0
insta_whore_tinder = 0

while like_quantity_tinder >= 1:
    passed = False
    # Sleep to avoid errors
    time.sleep(random.uniform(2.0, 3.0))
    # Click maybe later if it appears
    try:
        maybe_later = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/div/div[3]/button[2]/span').click()
    except Exception:
        pass
    # Open the description to read its text
    try:
        desc_button1 = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div[1]/div[2]/div[3]').click()
    except Exception:
        pass
    try:
        desc_button2 = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div[1]/div[3]/div[3]/div/div[2]/div/div').click()
    except Exception:
        pass
    try:
        desc_button3 = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div[1]/div[2]/div[3]/button').click()
    except Exception:
        pass
    try:
        desc_button4 = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div[1]/div[3]/div[3]/button').click()
    except Exception:
        pass
    try:
        desc_button5 = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div[1]/div[2]/div[3]/button/svg').click()
    except Exception:
        pass
    try:
        desc_button6 = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div[1]/div[3]/div[3]/button/svg').click()
    except Exception:
        pass
    # Sleep to avoid errors
    time.sleep(random.uniform(2.0, 4.0))
    # Get the name of the person
    try:
        name = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[2]/div[1]/div/div[1]/div/h1').text
    except Exception:
        try:
            desc_button1 = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div[1]/div[2]/div[3]').click()
        except Exception:
            pass
    # Get the age of the person
    age = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[2]/div[1]/div/div[1]/span').text
    try:
        # Count the number of photos
        photo_container = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[1]/span/div/div[1]')
        photo_count = len(photo_container.find_elements_by_xpath('./*'))
        # Define the number of times to scroll
        scrolling = range(0, random.randrange(1, photo_count))
        # Swipe through the photos
        for i in scrolling:
            # Start swiping through the photos
            actions = ActionChains(driver)
            actions.send_keys(Keys.SPACE)
            actions.perform()
            # Sleep to avoid errors
            time.sleep(random.uniform(2.0, 5.0))
    except Exception:
        pass
    # DO THE LIKING/PASSING
    try:
        # Retrieve the text of their description
        description = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[2]/div[2]').text
        # Sleep to avoid errors
        time.sleep(random.uniform(1.0, 2.0))
        # Loop through the exclusion list and check if each element in the description
        if len(description) <= 40:
            for i in insta_exclusion_list:
                if i in description:
                    # Pass button inside the FOR LOOP description
                    pass_button = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[2]/div/div/div[2]/button').click()
                    pass_quantity_tinder += 1
                    insta_whore_tinder += 1
                    # Append a row to the DataFrame
                    history_tinder = history_tinder.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'description', 'EXCEPTION': i}, ignore_index = True)
                    passed = True 
                    break
        for i in exclusion_list:
            # Passed get changed to true if the profile was passed in the above for loop
            if passed == True:
                break
            if i in description:
                # Pass button inside the FOR LOOP description
                pass_button = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[2]/div/div/div[2]/button').click()
                pass_quantity_tinder += 1
                had_exclusion_tinder += 1
                # Append a row to the DataFrame
                history_tinder = history_tinder.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'description', 'EXCEPTION': i}, ignore_index = True)
                break
            else:
                # Sleep to avoid errors
                time.sleep(random.uniform(1.0, 2.0))
                # Like button w/ description
                like_button = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[2]/div/div/div[4]/button').click()
                like_quantity_tinder -= 1
                likesUsed_tinder += 1
                # Append a row to the DataFrame
                history_tinder = history_tinder.append({'STATUS': 'liked', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': None, 'EXCEPTION': None}, ignore_index = True)
                # Sleep to avoid errors
                time.sleep(random.uniform(1.0, 3.0))
                # Click No Thanks when prompted about upgrading the like
                try:
                    no_thanks = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/button[2]').click()
                except Exception:
                    pass
                # Sleep to avoid errors
                time.sleep(random.uniform(1.0, 3.0))
                # If user runs out of likes
                try:
                    no_thanks_premium = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/div[3]/button[2]').click()
                except Exception:
                    pass
                break
    except Exception:
        # If description is blank and an exception is thrown, so we pass on this person
        # Sleep to avoid errors
        time.sleep(random.uniform(1.0, 2.0))
        # Pass button for empty description
        pass_button = driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[2]/div/div/div[2]/button').click()
        pass_quantity_tinder += 1
        no_desc_tinder += 1
        # Append a row to the DataFrame
        history_tinder = history_tinder.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'description', 'EXCEPTION': 'no description'}, ignore_index = True)
        pass
    # Sleep to avoid errors
    time.sleep(random.uniform(1.0, 3.0))
    # Click Not Interesed when asked about adding Tinder to the home screenb
    try:
        not_interested_button = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/div[2]/button[2]').click()
    except Exception:
        pass
    # Sleep to avoid errors
    time.sleep(random.uniform(1.0, 3.0))
    # Run out of likes and there's no option for "maybe later"
    try:
        message = driver.find_element_by_xpath('//*[@id="modal-manager"]/div/div/div[1]/div[2]/div[1]/span[1]/div/div/span/div/h3').text
        if message == "You're Out of Likes!":
            driver.close()
            passed = True 
    except Exception:
        pass
    # Passed get changed to true if the profile was passed in the above for loop
    if passed == True:
        break
try:
    # Close the Chrome window
    driver.close()
except Exception:
    pass
# Create new XLSX file including the appended rows
history_tinder.to_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, index = False)

# %%
# BUMBLE
service = 'Bumble'
# Read the swiping history XLSX into a DataFrame
history_bumble = pd.read_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, header = 0)
# Define the badges exclusion lists
    # Contents hidden
exercise_exclusion_list = []
education_exclusion_list = []
drinking_exclusion_list = []
smoking_exclusion_list = []
pets_exclusion_list = []
looking_for_exclusion_list = []
kids_exclusion_list = []
star_sign_exclusion_list = []
politics_exclusion_list = []
religion_exclusion_list = []
gender_exclusion_list = []
badge_exclusion_list = exercise_exclusion_list + education_exclusion_list + drinking_exclusion_list + smoking_exclusion_list + pets_exclusion_list + looking_for_exclusion_list + kids_exclusion_list + star_sign_exclusion_list + politics_exclusion_list + religion_exclusion_list + gender_exclusion_list 
# Define a start time
startTime = time.time()
# Define URL
bumble = 'https://bumble.com/'
# Instantiate an Options object
option = webdriver.ChromeOptions()
#Remove navigator.webdriver flag
option.add_argument('--disable-blink-features=AutomationControlled')
# Change the resolution of the browser
option.add_argument("window-size=1920,1080")
# Adjusting the user agent
option.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36")
#Open Browser
driver = webdriver.Chrome(executable_path='chromedriver.exe', options=option)
# Open the specfied URL
driver.get(bumble)
# Sleep to avoid errors
time.sleep(random.uniform(2.0, 4.0))
# Define the Tinder window
window_bumble = driver.window_handles[0]
# Click the Sign In button
sign_in_button = driver.find_element_by_xpath('//*[@id="page"]/div/div/div[1]/div/div[2]/div/div/div/div[2]/div[1]/div/div[2]/a').click()
# Sleep to avoid errors
time.sleep(random.uniform(3.0, 5.0))
# Click the Continue with Facebook button
facebook_button = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/div[2]/main/div/div[3]/form/div[1]/div/div[2]/div').click()
# Sleep to avoid errors
time.sleep(random.uniform(1.0, 2.0))
# Define the Facebook window
window_facebook = driver.window_handles[1]
# Switch to the Facebook window
driver.switch_to_window(window_facebook)
# Find the Email or Phone input field and type email
email_field = driver.find_element_by_xpath('/html/body/div/div[2]/div[1]/form/div/div[1]/div/input').send_keys(emailFB)
# Find the password input field and type PW
PW_field = driver.find_element_by_xpath('/html/body/div/div[2]/div[1]/form/div/div[2]/div/input').send_keys(pwFB)
# Click the login button
login_button_facebook = driver.find_element_by_xpath('//*[@id="u_0_0"]').click()
# Sleep to avoid errors
time.sleep(random.uniform(2.0, 3.0))
# Switch to the Bumble window
driver.switch_to_window(window_bumble)
# Sleep to avoid errors
time.sleep(random.uniform(3.0, 5.0))

# THIS IS WHERE THE WHILE LOOP WILL START
like_quantity_bumble = random.randrange(10, 20)
pass_quantity_bumble = 0
no_desc_bumble = 0
had_exclusion_bumble = 0
likesUsed_bumble = 0

while like_quantity_bumble >= 1:
    passed = False
    # Sleep to avoid errors
    time.sleep(random.uniform(2.0, 4.0))
    # Count the number of slides
    slides = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[1]/article/div[1]')
    slide_count = len(slides.find_elements_by_xpath('./*'))
    # Define the number of times to scroll
    scrolling = range(0, random.randrange(1, slide_count + 1))
    # Get the name of the person
    name = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[1]/article/div[1]/div[1]/article/div[2]/section/header/h1/span[1]').text
    # Get the age of the person
    age = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[1]/article/div[1]/div[1]/article/div[2]/section/header/h1/span[2]').text
    # Scroll through the slides
    for i in scrolling:
        # Click once to go down a slide
        scroll_down = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[1]/article/div[2]/div[2]').click()
        # Sleep to avoid errors
        time.sleep(random.uniform(2.0, 5.0))
    # About Text
    try:
        about_text = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[1]/article/div[1]/div[2]/article/div/section/div/p').get_attribute('innerHTML')
    except Exception:
        # Pass Button
        pass_button = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[2]/div/div[2]/div/div[1]/div').click()
        pass_quantity_bumble += 1
        no_desc_bumble += 1
        # Append a row to the DataFrame
        history_bumble = history_bumble.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'description', 'EXCEPTION': 'no description'}, ignore_index = True) 
        continue      
    try: 
        # Badges
        badgesCount = len(driver.find_elements_by_class_name('encounters-story-about__badge'))
        badges_text = [driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[1]/article/div[1]/div[2]/article/div/section/div/ul/li[{}]/div/div[2]/div'.format(i)).get_attribute('innerHTML') for i in range(1, badgesCount + 1)]
    except Exception:
        badges_text = []
        # Pass Button
        pass_button = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[2]/div/div[2]/div/div[1]/div').click()
        pass_quantity_bumble += 1
        no_desc_bumble += 1
        # Append a row to the DataFrame
        history_bumble = history_bumble.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'badges', 'EXCEPTION': 'no badges'}, ignore_index = True) 
        continue
    for i in badge_exclusion_list:
        if i in badges_text:
            # Pass Button
            pass_button = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[2]/div/div[2]/div/div[1]/div').click()
            pass_quantity_bumble += 1
            had_exclusion_bumble += 1
            # Append a row to the DataFrame
            history_bumble = history_bumble.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'badges', 'EXCEPTION': i}, ignore_index = True) 
            passed = True 
            break
    # Passed get changed to true if the profile was passed in the above for loop
    if passed == True:
        continue
    for i in exclusion_list:
        if i in about_text:
            # Pass Button
            pass_button = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[2]/div/div[2]/div/div[1]/div').click()
            pass_quantity_bumble += 1
            had_exclusion_bumble += 1
            history_bumble = history_bumble.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'description', 'EXCEPTION': i}, ignore_index = True) 
            passed = True 
            break
    # Passed get changed to true if the profile was passed in the above for loop
    if passed == True:
        continue
    # Like Button
    like_button = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/div/div/span/div[2]/div/div[2]/div/div[3]/div').click()
    like_quantity_bumble -= 1
    likesUsed_bumble += 1
    history_bumble = history_bumble.append({'STATUS': 'liked', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': None, 'EXCEPTION': None}, ignore_index = True) 
    try:
        continue_bumbling_button = driver.find_element_by_xpath('//*[@id="main"]/div/div[1]/main/div[2]/article/div/footer/div[2]/div[2]/div').click()
    except Exception:
        pass
# Close the Chrome window
driver.close()
# Create new XLSX file including the appended rows
history_bumble.to_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, index = False)

# %%
# OKCUPID
service = 'OkCupid'
pw = ''
# Read the swiping history XLSX into a DataFrame
history_okcupid = pd.read_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, header = 0)
# Define exclusions lists
    # Contents hidden
basics_exclusion_list = []
looks_exclusion_list = []
background_exclusion_list = []
lifestyle_exclusion_list = []
family_exclusion_list = []
# Define a start time
startTime = time.time()
# Define URL
okcupid = 'https://www.okcupid.com'
# Instantiate an Options object
option = webdriver.ChromeOptions()
#Remove navigator.webdriver flag
option.add_argument('--disable-blink-features=AutomationControlled')
# Change the resolution of the browser
option.add_argument("window-size=1920,1080")
# Adjusting the user agent
option.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36")
#Open Browser
driver = webdriver.Chrome(executable_path='chromedriver.exe', options=option)
# Open the specfied URL
driver.get(okcupid)
# Sleep to avoid errors
time.sleep(random.uniform(2.0, 4.0))
# Define the OkCupid window
window_okcupid = driver.window_handles[0]
# Click the Sign In button
sign_in_button = driver.find_element_by_xpath('//*[@id="main_content"]/div/div/div[1]/div[2]/a').click()
# Sleep to avoid errors
time.sleep(random.uniform(1.0, 2.0))
# Click accept cookies
cookies_okay = driver.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()
# Find the Email or Phone input field and type email
email_field = driver.find_element_by_xpath('//*[@id="username"]').send_keys(emailFB)
# Find the password input field and type PW
PW_field = driver.find_element_by_xpath('//*[@id="password"]').send_keys(pw)
# Click the Next button
try:
    next_button = driver.find_element_by_xpath('//*[@id="OkModal"]/div/div[1]/div/div/div/div[2]/div/div/div[2]/div/form/div[2]/button[1]').click()
except Exception:
    pass
# Click the login button
#login_button = driver.find_element_by_xpath('//*[@id="OkModal"]/div/div[1]/div/div/div/div[2]/div/div/div[2]/div/form/div[2]/input').click()
# Sleep to avoid errors
time.sleep(random.uniform(7.0, 12.0))
# Define global variables
like_quantity_okcupid = random.randrange(5, 10)
pass_quantity_okcupid = 0
had_exclusion_okcupid = 0
likesUsed_okcupid = 0
profile_number = 0
# Concetentate all the exclusion lists
exclusion_list = basics_exclusion_list + looks_exclusion_list + lifestyle_exclusion_list + family_exclusion_list + background_exclusion_list
# Begin looping through the profiles of potential matches
while like_quantity_okcupid >= 1:
    passed = False
    # Sleep to avoid errors
    time.sleep(random.uniform(10.0, 20.0))
    # Increment the profile number
    profile_number += 1
    # Get the name of the person
    name = driver.find_element_by_xpath('//*[@id="main_content"]/div[3]/div/div[1]/div/div/div/div/div[1]/div[1]/span[1]').text
    # Get the age of the person
    age = driver.find_element_by_xpath('//*[@id="main_content"]/div[3]/div/div[1]/div/div/div/div/div[1]/div[1]/span[2]').text
    # Count the amount of details provided
    details = driver.find_element_by_xpath('//*[@id="main_content"]/div[3]/div/div[3]/div[1]')
    details_count = int(len(details.find_elements_by_xpath('.//*')) / 7)
    # Loop through the details and extract their text
    text = {}
    details_text = ''
    for i in range(1, details_count + 1):
        text[i] = driver.find_element_by_xpath('//*[@id="main_content"]/div[3]/div/div[3]/div[1]/div[{}]/div'.format(i)).text
        # Append the text[i] string to the string that contains all the extracted text
        details_text += text[i] + ". "
    # Loop through the ALL exclusions to see if they're present in the ALL extracted text
    for i in exclusion_list:
        # Checks for any exception in the details
        if i in details_text:
            # Pass button
            pass_button = driver.find_element_by_xpath('//*[@id="main_content"]/div[3]/div/div[1]/div/div/div/div/div[1]/div[2]/button[1]').click()
            pass_quantity_okcupid += 1
            had_exclusion_okcupid += 1
            passed = True
            history_okcupid = history_okcupid.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'details', 'EXCEPTION': i}, ignore_index = True) 
            break
        else:
            continue
    # Passed get changed to true if the profile was passed in the above for loop
    if passed == True:
        continue
    # Check for an absence of Thin/Fit/Athletic
    if 'Thin' not in details_text and 'Fit' not in details_text and 'Athletic' not in details_text:
        # Pass button
        pass_button = driver.find_element_by_xpath('//*[@id="main_content"]/div[3]/div/div[1]/div/div/div/div/div[1]/div[2]/button[1]').click()
        pass_quantity_okcupid += 1
        had_exclusion_okcupid += 1
        history_okcupid = history_okcupid.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'looks', 'EXCEPTION': 'NOT fit/thin/athletic'}, ignore_index = True)
        continue
    # If passed is False still, then we like the current profile
    # Like button
    like_button = driver.find_element_by_xpath('//*[@id="main_content"]/div[3]/div/div[1]/div/div/div/div/div[1]/div[2]/button[2]').click()
    like_quantity_okcupid -= 1
    likesUsed_okcupid += 1
    history_okcupid = history_okcupid.append({'STATUS': 'liked', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': None, 'EXCEPTION': None}, ignore_index = True)
    # Handle matches
    try:
        close_match = driver.find_element_by_xpath('//*[@id="main_content"]/div[4]/div[2]/div[2]/div/div/div/div/div/div/div[1]/div[1]/button').click()
    except Exception:
        pass
    # Break out of the while loop if passes equal:
    if pass_quantity_okcupid >= random.randrange(20, 25):
        break
# Create new XLSX file including the appended rows
history_okcupid.to_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, index = False)
# Close the web browser
driver.close()

# %%
# PLENTYOFFISH
service = 'Plenty of Fish'
# Read the swiping history XLSX into a DataFrame
history_pof = pd.read_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, header = 0)
# Define PW
pw = ''
# Define a start time
startTime = time.time()
# Exclusion lists
    # Contents hidden
education_exclusion_list = []
smoking_exclusion_list = []
religion_exclusion_list = []
kids_exclusion_list = []
body_type_exclusion_list = []
# Define URL
plentyoffish = 'https://www.pof.com/'
# Instantiate an Options object
option = webdriver.ChromeOptions()
#Remove navigator.webdriver flag
option.add_argument('--disable-blink-features=AutomationControlled')
# Change the resolution of the browser
option.add_argument("window-size=1920,1080")
# Adjusting the user agent
option.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36")
# Open Browser
driver = webdriver.Chrome(executable_path='chromedriver.exe', options=option)
# Instantiate an Action Chains object
actionChains = ActionChains(driver)
# Open the specfied URL
driver.get(plentyoffish)
# Sleep to avoid errors
time.sleep(random.uniform(2.0, 4.0))
# Define the PoF window
window_PoF = driver.window_handles[0]
# Switch to the PoF window
driver.switch_to_window(window_PoF)
# Click the Accept button for cookies
cookies_okay = driver.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()
# Click the Sign In button
sign_in_button = driver.find_element_by_xpath('//*[@id="gatsby-focus-wrapper"]/div[1]/header/nav/ul/li[1]').click()
# Sleep to avoid errors
time.sleep(random.uniform(1.0, 2.0))
# Find the Email or Phone input field and type email
email_field = driver.find_element_by_xpath('//*[@id="login-username"]').send_keys(emailFB)
# Sleep to avoid errors
time.sleep(random.uniform(1.0, 2.0))
# Find the password input field and type PW
PW_field = driver.find_element_by_xpath('//*[@id="login-password"]').send_keys(pw)
# Click the login button
login_button = driver.find_element_by_xpath('//*[@id="login-submit"]').click()
# Sleep to avoid errors
time.sleep(random.uniform(8.0, 12.0))
# Click the Meet Me button
meet_me = driver.find_element_by_xpath('//*[@id="main-navigation"]/nav/ul/li[2]').click()
# Sleep to avoid errors
time.sleep(random.uniform(2.0, 4.0))
# Define global variables
like_quantity_pof = random.randrange(5, 10)
pass_quantity_pof = 0
had_exclusion_pof = 0
likesUsed_pof = 0
# Open a new tab
driver.execute_script("window.open('');")
# Switch to the new tab
driver.switch_to.window(driver.window_handles[1])
# Open the new site in the new tab
driver.get('https://www.mapdevelopers.com/distance_from_to.php')
# Switch to the PoF window
driver.switch_to.window(driver.window_handles[0])
# Begin looping through the profiles of potential matches
while like_quantity_pof >= 1:  
    passed = False
    # Sleep to avoid errors
    time.sleep(random.uniform(3.0, 6.0))
    # Close the popup
    try: 
        take_a_look = driver.find_element_by_xpath('//*[@id="first-super-yes-dialog-dialog-contents"]/button').click()
    except Exception:
        pass
    # Sleep to avoid errors
    time.sleep(random.uniform(1.0, 2.0))
    # Click into the person's profile
    profile_list = ['//*[@id="meeetme-stack"]/div[10]/div[1]/div[1]', '//*[@id="meeetme-stack"]/div[1]/div[1]/div[1]/div/div', '//*[@id="meeetme-stack"]/div[1]/div[1]/div[1]/div', '//*[@id="meeetme-stack"]/div[1]/div[1]/div[1]', '//*[@id="meeetme-stack"]/div[1]', '//*[@id="meeetme-stack"]/div[1]/div[1]/div[1]/div/div/a/div[2]', '//*[@id="287785340-meet-me-image-screenreader"]']
    for i in profile_list:
        try:
            profile = driver.find_element_by_xpath(i).click()
        except Exception:
            pass
    # Sleep to avoid errors
    time.sleep(random.uniform(10.0, 20.0))
    # Get name
    name = driver.find_element_by_xpath('//*[@id="profile-banner"]/div[2]/div[3]/div[1]/div[2]/div[1]/h1').text
    # Get location
    location = driver.find_element_by_xpath('//*[@id="attributelist-item-location"]').text
    location = location.split("\n")[1]
    # Switch to the distance tab
    driver.switch_to.window(driver.window_handles[1])     
    # Enter my home city
    distance_from = driver.find_element_by_xpath('//*[@id="fromInput"]').clear()
    distance_from = driver.find_element_by_xpath('//*[@id="fromInput"]').send_keys('Barrington, IL')
    # Enter their city
    distance_to = driver.find_element_by_xpath('//*[@id="toInput"]').clear()
    distance_to = driver.find_element_by_xpath('//*[@id="toInput"]').send_keys(location)
    # Hit the Calcualat Distance button
    calculate_distance = driver.find_element_by_xpath('/html/body/div[1]/table/tbody/tr[3]/td/table/tbody/tr[2]/td/span/form/a').click()
    # Sleep to avoid errors
    time.sleep(random.uniform(5.0, 8.0))
    # Copy the distance in miles
    distance = driver.find_element_by_xpath('//*[@id="status"]').text
    distance = re.findall("\d+\.\d+", distance)
    distance = float(distance[0])
    # Switch to the PoF window
    driver.switch_to.window(driver.window_handles[0])
    # Get age
    age = driver.find_element_by_xpath('//*[@id="profile-banner"]/div[2]/div[3]/div[1]/div[2]/div[2]').text
    age = int(age.split(",")[0][0:2])
    # Get education
    education = driver.find_element_by_xpath('//*[@id="attributelist-item-education"]').text
    education = education.split("\n")[1]
    # Sleep to avoid errors
    time.sleep(random.uniform(2.0, 4.0))
    # Get smoking
    smoking = driver.find_element_by_xpath('//*[@id="attributelist-item-smoke"]').text
    smoking = smoking.split("\n")[1]
    # Get religion
    religion = driver.find_element_by_xpath('//*[@id="attributelist-item-religion"]').text
    religion = religion.split("\n")[1]
    # Get kids
    kids = driver.find_element_by_xpath('//*[@id="attributelist-item-hasKids"]').text
    kids = kids.split("\n")[1]
    # Get body type
    body_type = driver.find_element_by_xpath('//*[@id="attributelist-item-bodyType"]').text
    body_type = body_type.split("\n")[1]
    # Go back
    driver.back()
    # Sleep to avoid errors
    time.sleep(random.uniform(2.0, 4.0))
    # Get the number of cards
    card_holder = driver.find_element_by_xpath('//*[@id="meeetme-stack"]')
    card_count = int(len(card_holder.find_elements_by_xpath('./*')))
    # Filter out people who are too far away
    if distance > 40.0:
        if "Chicago" not in location or "Burbs" not in location or "Suburbs" not in location:
            # Sleep to avoid errors
            time.sleep(random.uniform(2.0, 4.0))
            # Pass button
            pass_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-no"]').click()
            history_pof = history_pof.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'distance', 'EXCEPTION': 'distance > 40 miles', 'DISTANCE': distance}, ignore_index = True)
            pass_quantity_pof += 1
            had_exclusion_pof += 1
            continue
    # Filter out unwanted ages
    if age > 30 or age < 25:
        # Sleep to avoid errors
        time.sleep(random.uniform(2.0, 4.0))
        # Pass button
        pass_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-no"]').click()
        history_pof = history_pof.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'age', 'EXCEPTION': 'age > 30 or age < 25', 'DISTANCE': distance}, ignore_index = True)
        passed = True
        pass_quantity_pof += 1
        had_exclusion_pof += 1
        continue
    # Filter out unwanted educational backgrounds
    for i in education_exclusion_list:
        if i in education:
            # Sleep to avoid errors
            time.sleep(random.uniform(2.0, 4.0))
            # Pass button
            pass_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-no"]').click()
            history_pof = history_pof.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'education', 'EXCEPTION': i, 'DISTANCE': distance}, ignore_index = True)
            passed = True
            pass_quantity_pof += 1
            had_exclusion_pof += 1
            break
    # Skip to the next profile if pass is clicked
    if passed == True:
        continue
    # Filter out unwanted smoking habits
    for i in smoking_exclusion_list:
        if i in smoking:
            # Sleep to avoid errors
            time.sleep(random.uniform(2.0, 4.0))
            # Pass button
            pass_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-no"]').click()
            history_pof = history_pof.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'smoking', 'EXCEPTION': i, 'DISTANCE': distance}, ignore_index = True)
            passed = True
            pass_quantity_pof += 1
            had_exclusion_pof += 1
            break
    # Skip to the next profile if pass is clicked
    if passed == True:
        continue
    # Filter out unwanted religious affiliations
    for i in religion_exclusion_list:
        if i in religion:
            # Sleep to avoid errors
            time.sleep(random.uniform(2.0, 4.0))
            # Pass button
            pass_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-no"]').click()
            history_pof = history_pof.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'religion', 'EXCEPTION': i, 'DISTANCE': distance}, ignore_index = True)
            passed = True
            pass_quantity_pof += 1
            had_exclusion_pof += 1
            break
    # Skip to the next profile if pass is clicked
    if passed == True:
        continue
    # Filter out profiles with kids
    for i in kids_exclusion_list:
        if i in kids:
            # Sleep to avoid errors
            time.sleep(random.uniform(2.0, 4.0))
            # Pass button
            pass_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-no"]').click()
            history_pof = history_pof.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'kids', 'EXCEPTION': i, 'DISTANCE': distance}, ignore_index = True)
            passed = True
            pass_quantity_pof += 1
            had_exclusion_pof += 1
            break
    # Skip to the next profile if pass is clicked
    if passed == True:
        continue
    # Filter out unwanted body types
    for i in body_type_exclusion_list:
        if i in body_type:
            # Sleep to avoid errors
            time.sleep(random.uniform(2.0, 4.0))
            # Pass button
            pass_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-no"]').click()
            history_pof = history_pof.append({'STATUS': 'passed', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': 'body type', 'EXCEPTION': i, 'DISTANCE': distance}, ignore_index = True)
            passed = True
            pass_quantity_pof += 1
            had_exclusion_pof += 1
            break
    # Skip to the next profile if pass is clicked
    if passed == True:
        continue
    # Finally, if they made it past all the filters, toss a like their way!
    # Sleep to avoid errors
    time.sleep(random.uniform(1.0, 2.0))
    # Like button 
    like_button = driver.find_element_by_xpath('//*[@id="meetmevotebutton-yes"]').click()
    like_quantity_pof -= 1
    likesUsed_pof += 1
    history_pof = history_pof.append({'STATUS': 'liked', 'DATE': date, 'NAME': name, 'AGE': age,'EXCEPTION_LOCATION': None, 'EXCEPTION': None, 'DISTANCE': distance}, ignore_index = True)
    # Close the popup
    try: 
        take_a_look = driver.find_element_by_xpath('//*[@id="first-super-yes-dialog-dialog-contents"]/button').click()
    except Exception:
        pass
    # Break out of the while loop if passes equal:
    if pass_quantity_pof >= random.randrange(20, 25):
        break
# Create new XLSX file including the appended rows
history_pof.to_excel(r'Data\{}.xlsx'.format(service), sheet_name = service, index = False)
# Close the current tab
driver.close()
# Switch to the first tab and close it
driver.switch_to.window(driver.window_handles[0])
driver.close()
